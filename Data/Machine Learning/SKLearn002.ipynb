# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame
lsd = pd.read_csv('latprice.csv')
lsd.head()
# Out:
#    latitude  price
# 0 -32.00871    202
# 1 -32.06806     72
# 2 -29.25216     94
# 3 -32.00395    180
# 4 -34.35542    440

# %%
y = lsd.latitude.values.reshape(-1, 1)
x = lsd.price.values.reshape(-1, 1)

print("Shape: ", x.shape, y.shape)
x
# Out:
# Shape:  (12454, 1) (12454, 1)
# array([[ 202],
#        [  72],
#        [  94],
#        ...,
#        [ 138],
#        [1102],
#        [ 833]], dtype=int64)

# %%
plt.scatter(x, y)

# %%
from sklearn.linear_model import LinearRegression

### BEGIN SOLUTION

model = LinearRegression()

### END SOLUTION

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[8.68866446e-07]]
# y-axis intercept:  [-32.03167081]

# %%
x_min = np.array([[x.min()]])
x_max = np.array([[x.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[0]]
# Max X Value: [[360000]]

# %%
y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
plt.scatter(x, y, c='blue')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
