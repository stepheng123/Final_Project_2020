# %%
# This model is to predict the prices of airbnb rental based on number of reviews

# setting up the Pandas
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame
lsd = pd.read_csv('numreview.csv')
lsd = lsd.loc[lsd['price']<2000]
lsd = lsd.loc[lsd['price']>1]
lsd
# Out:
#        price  number_of_reviews
# 14      1999                  1
# 15      1999                  5
# 16      1999                  0
# 17      1500                 69
# 18      1500                  1
# ...      ...                ...
# 12444     14                  0
# 12445     14                  3
# 12446     14                 18
# 12447     14                  0
# 12448     14                  0
#
# [12435 rows x 2 columns]

# %%
#reset the values into the model
y = lsd.price.values.reshape(-1, 1)
x = lsd.number_of_reviews.values.reshape(-1, 1)

print("Shape: ", x.shape, y.shape)
y
# Out:
# Shape:  (12435, 1) (12435, 1)
# array([[1999],
#        [1999],
#        [1999],
#        ...,
#        [  14],
#        [  14],
#        [  14]], dtype=int64)

# %%
# show the results in a scatter plot
plt.scatter(x, y)

# %%
from sklearn.linear_model import LinearRegression

### BEGIN SOLUTION

model = LinearRegression()

### END SOLUTION

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[-0.3704877]]
# y-axis intercept:  [183.04416614]

# %%
x_min = np.array([[x.min()]])
x_max = np.array([[x.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[0]]
# Max X Value: [[810]]

# %%
y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
plt.scatter(x, y, c='blue')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')

# %%
# This results showed that the prediction was not practical as prices couldn't be determined by using the number of reviews.
