# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
dollar = pd.read_csv('numreview.csv')
dollar = dollar.loc[dollar['price']<2000]
dollar = dollar.loc[dollar['price']>1]

# %%
y = dollar.price.values.reshape(-1, 1)
x = dollar.number_of_reviews.values.reshape(-1, 1)

print("Shape: ", x.shape, y.shape)
y
# Out:
# Shape:  (12435, 1) (12435, 1)
# array([[1999],
#        [1999],
#        [1999],
#        ...,
#        [  14],
#        [  14],
#        [  14]], dtype=int64)

# %%
plt.scatter(x, y)

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=2, random_state=0)
regr.fit(x,y)
# Out:
# RandomForestRegressor(max_depth=2, random_state=0)

# %%
print(regr.predict([[300]]))
# Out:
# [125.72018713]
